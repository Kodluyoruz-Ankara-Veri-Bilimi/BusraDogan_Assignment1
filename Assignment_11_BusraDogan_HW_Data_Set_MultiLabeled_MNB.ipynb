# %% [markdown]
# # BusraDoganHW_Data_Set

# %% [markdown]
# ## Importing Libraries

# %%
# LIBRARIES                         
import pandas as pd
import numpy as np

import collections
import math

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler


#Machine learning algorithms libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB,GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# import statsmodels.api as sm
from scipy import stats
# import scipy.stats
from scipy.stats import shapiro
from scipy.stats import levene

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.23.1.

# %%
import scipy
scipy.version.full_version
# Out:
# '1.5.0'

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.7

# %%
class datasetAnalysis:

    
    def __init__(self,data,target):
        self.data=data
        self.target=target

    def datasetInfo1(self):
        
        print( '\033[1m'+ "\n Shape of Dataset :" + '\033[0m',self.data.shape)
        print(self.data.info())
        print(self.data.describe())
        print( '\033[1m'+ "\n General Information of Dataset\n" + '\033[0m',self.data.head())
        print('\033[1m'+ " \n Showing Missing Values\n" + '\033[0m')
        print(self.data.isnull().sum())
        
        
    def datasetInfo2(self):
        print(self.data.columns)
        print("\n" , '\033[1m'+ "Target Counts\n" + '\033[0m', self.data[target].value_counts(),"\n")
        
        for i in self.data.columns:
            print(self.data[i].value_counts().head(7),"\n")


class PreVisulation:
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    def __init__(self,data,feature):
#         self.data=data
#         self.target=target
        self.feature=feature
        self.data=data

    def vis1(self):
        
    #target distribution
        print(data[target].value_counts())
        sns.set(style="darkgrid")
        ax= sns.countplot(y="reason", hue=target, data=data)
        
#         data[target].value_counts().plot("barh")
    def vis2(self): 
        
        data[feature].plot.hist(bins = 20,figsize=(15,7.5))
        
        
        
    def vis3(self): 
        
        
        for i in range(len(self.data.dtypes)):

               
            
            if (self.data.dtypes[i] != "object" and self.data.iloc[:,i].notna().all()):

                f,axes = newplt.subplots(1,1)
                sns.distplot(self.data.iloc[:,i],kde_kws=dict(linewidth=5),bins = 20)
                
            elif (self.data.dtypes[i] == "object" and self.data.iloc[:,i].notna().all()):
                f,axes = newplt.subplots(1,1)
                sns.countplot(self.data.iloc[:,i],data=self.data)
        
        # Verinin boxplot gösterimi
        newplt.figure()
        sns.boxplot(data=self.data)

# %%
class preprocess():
    from sklearn.impute import SimpleImputer
    
    def __init__(self, data):
        self.data=data
    
    def missingvalues(self):
        # Imputation
#         if self.data.col.dtypes == 'object':
                        
#             self.data[col] = self.data[col].replace(np.nan, "Other")
#             print(self.data.isna().sum())
#         else:
        my_imputer = SimpleImputer()
        imputed_df2_dum = pd.DataFrame(my_imputer.fit_transform(self.data))
        imputed_df2_dum.columns = self.data.columns
        self.data=imputed_df2_dum.copy()
    
    def dummies(self):
        df=data
    
        df_num = df.select_dtypes(exclude=[np.number])
        df_num.columns
        a=df_num.columns
        dff=self.data.copy()
    #     s = (df2.dtypes == 'object')
    #     object_cols = list(s[s].index)
        for i in a:
            if self.data[i].value_counts().count() <= 6:


                df2_dum = pd.get_dummies(self.data[i],columns= i, prefix= i) #prefix_sep = '_'
                print(list(df2_dum.columns))
                dff = pd.concat([dff, df2_dum], axis=1).drop(i,axis=1)
                print(list(dff.columns))
        self.data=dff.copy()        
        return self.data

# %%
class process():
    global train
    global test
    
    
    def __init__(self,X,y,size):
     
        self.size=size
        self.X=X
        self.y=y
    
    def split(self):
        
        # train-test spit
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size=self.size,stratify=df[target],shuffle=True,random_state=42)#shuffle=False,
        

        print("\n", '\033[1m'+ " X_train,X_test Info" + '\033[0m')
        print(X_train.shape,X_test.shape)
        print("\n", '\033[1m'+ " X_train,y_test Info" + '\033[0m')
        print(y_train.shape,y_test.shape)
        return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Reading The Dataset

# %%
#read data 
from pandas import read_excel
df = pd.read_excel('HW_Data_Set.xlsx')

# %%
df["90_target"].plot.hist(bins = 20,figsize=(15,7.5))

# %%
df["90_target"].describe()
# Out:
# count    6167.000000
# mean       -3.315072
# std        36.841541
# min       -38.573858
# 25%       -37.695273
# 50%       -35.788391
# 75%        37.521892
# max        38.465649
# Name: 90_target, dtype: float64

# %%
df.columns
# Out:
# Index(['ind_5', 'ind_6', 'ind_8', 'ind_9', 'ind_10', 'ind_12', 'ind_13',
#        'ind_14', 'ind_15', 'ind_16',
#        ...
#        'ind_416', 'ind_418', 'ind_420', 'ind_422', 'ind_424', 'ind_426',
#        'ind_428', '20_target', '50_target', '90_target'],
#       dtype='object', length=136)

# %% [markdown]
# # Converting to MultiLabeled Target

# %%
target_obj_90=[]

for i in df['90_target']: 
    
    if (i >= -38.0) &( i <= -15.0):
    
        target_obj_90.append(1)
    
    elif (i <= 38.0) & (i >= 15.0):
    
        target_obj_90.append(3)
        
    else :
        
        target_obj_90.append(2)
    
df['labeled_90_target'] = target_obj_90

# %% [markdown]
# # Description of Variables¶

# %%
target='target_obj_90'
data=datasetAnalysis(df,target)
data.datasetInfo1()
# Out:
#  Shape of Dataset : (6167, 137)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6167 entries, 0 to 6166
# Columns: 137 entries, ind_5 to labeled_90_target
# dtypes: float64(88), int64(46), object(3)
# memory usage: 6.4+ MB
# None
#              ind_5        ind_6        ind_8        ind_9       ind_10  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean     -0.803146    -0.803470    48.388890    48.289282     0.099609
# std      23.624403    23.624144    36.388526    36.478009    60.414625
# min    -131.000000  -131.000000     0.000000     0.000000  -100.000000
# 25%     -14.000000   -14.000000    14.285714    14.285714   -50.000000
# 50%       0.000000     0.000000    50.000000    50.000000     0.000000
# 75%      13.000000    13.000000    85.714286    85.714286    57.142857
# max      76.000000    76.000000   100.000000   100.000000   100.000000
#
#             ind_12       ind_13       ind_14       ind_15       ind_16  ...  \
# ...

# %%
data=df.copy()
data.head(5)
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target  labeled_90_target
# ...

# %%
data.shape
# Out:
# (6167, 137)

# %%
df= data.copy()
df = df.dropna(how="any")
df.shape
# Out:
# (6167, 137)

# %%
df.select_dtypes(include=['object'])
# Out:
#      ind_109 ind_420 ind_422
# 0      GREEN    -152    -353
# 1      GREEN    -158    -359
# 2      GREEN    -160    -362
# 3      GREEN    -166    -367
# 4      GREEN    -186    -388
# ...      ...     ...     ...
# 6162     RED     -11    -270
# 6163     RED     -12    -271
# 6164   GREEN     -21    -280
# 6165   GREEN     -33    -292
# 6166   GREEN     -28    -288
#
# [6167 rows x 3 columns]

# %%
data.ind_109.describe()
# Out:
# count      6167
# unique        2
# top       GREEN
# freq       3132
# Name: ind_109, dtype: object

# %%
data["ind_420"].describe()
# Out:
# count     6167
# unique     582
# top          ?
# freq      1041
# Name: ind_420, dtype: object

# %%
data.columns
# Out:
# Index(['ind_5', 'ind_6', 'ind_8', 'ind_9', 'ind_10', 'ind_12', 'ind_13',
#        'ind_14', 'ind_15', 'ind_16',
#        ...
#        'ind_418', 'ind_420', 'ind_422', 'ind_424', 'ind_426', 'ind_428',
#        '20_target', '50_target', '90_target', 'labeled_90_target'],
#       dtype='object', length=137)

# %%
data.corr().iloc[:,130:133]
# Out:
#                    20_target  50_target  90_target
# ind_5               0.060969   0.068989   0.060428
# ind_6               0.062101   0.069652   0.061560
# ind_8              -0.004126   0.006984  -0.006650
# ind_9              -0.031316  -0.004053   0.012093
# ind_10              0.016423   0.006654  -0.011307
# ...                      ...        ...        ...
# ind_428             0.047041   0.052418   0.043563
# 20_target           1.000000   0.384076   0.355950
# 50_target           0.384076   1.000000   0.940916
# 90_target           0.355950   0.940916   1.000000
# labeled_90_target   0.328888   0.844316   0.897738
#
# [134 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize=(5, 30))
sns.heatmap(data.corr().iloc[:,130:134], ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %% [markdown]
# # Visualization

# %%
sns.violinplot(x ='labeled_90_target', y ='ind_412', data = data,color='yellow')

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[["20_target", "50_target","90_target","labeled_90_target"]]
boxplot_df.boxplot()
plt.show()
# box ile tüm features bak ve outlier durumunu incele

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[[ 'ind_239', 'ind_309', 'ind_310', 'ind_324', 'ind_327', 'ind_332', 'ind_344',   'ind_412', 'ind_416']]
boxplot_df.boxplot()
plt.show()

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[[ 'ind_239', 'ind_309', 'ind_310', 'ind_324',  'ind_344',   'ind_412']]
boxplot_df.boxplot()
plt.show()

# %%
sns.distplot(data["labeled_90_target"])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(7,7))
sns.scatterplot(x="ind_310", y= "ind_412",hue= "labeled_90_target",data=data)

# %%
data["ind_420"].describe()
# Out:
# count     6167
# unique     582
# top          ?
# freq      1041
# Name: ind_420, dtype: object

# %%
# dff=data.drop(labels=["ind_420","ind_422"],axis=1,inplace=True)
df2=data.replace('?',np.nan)

# %%
df2.shape
# Out:
# (6167, 137)

# %%
df2.loc[df2['ind_420'].isnull(),'ind_420':]
# Out:
#       ind_420  ind_422   ind_424   ind_426   ind_428  20_target  50_target  \
# 57        NaN      NaN  0.971429  0.178117  0.284799 -15.116561  35.579963
# 58        NaN      NaN  0.983333  0.236908  0.305455 -15.119579  35.587067
# 59        NaN      NaN  1.000000  0.302326  0.319073 -15.121214  35.590915
# 60        NaN      NaN  1.000000  0.390519  0.369295 -15.131401  35.614892
# 61        NaN      NaN  0.870000  0.398104  0.327241 -15.121465  35.591507
# ...       ...      ...       ...       ...       ...        ...        ...
# 1791      NaN      NaN  1.000000  0.858397  0.705635 -15.510827 -36.507950
# 1792      NaN      NaN  0.000000  0.697733  0.682281 -15.499005 -36.480126
# 1793      NaN      NaN  0.000000  0.596639  0.680818 -15.508689 -36.502918
# 1794      NaN      NaN  1.000000  0.600666  0.690900 -15.507054 -36.499070
# 1795      NaN      NaN  0.245614  0.417857  0.663086  15.494604 -36.469765
#
#       90_target  labeled_90_target
# ...

# %% [markdown]
# # Categorical Variables to Numerical

# %%
dfImputer=preprocess(df2)

aa=dfImputer.dummies()
# Out:
# ['ind_109_GREEN', 'ind_109_RED']
# ...

# %%
aa.reset_index(drop=True, inplace=True)

dff=aa.copy()

# %%
dff
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %% [markdown]
# # Solve NaN Values with Imputer

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer()
imputed_df2_dum = pd.DataFrame(my_imputer.fit_transform(dff))
imputed_df2_dum.columns = dff.columns

# %%
imputed_df2_dum
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0      19.0   17.0  100.000000  85.714286  14.285714  72.363515  60.808814
# 1      24.0   19.0  100.000000  78.571429  21.428571  74.275883  64.366798
# 2      30.0   24.0  100.000000  71.428571  28.571429  75.140402  65.915803
# 3      37.0   30.0  100.000000  64.285714  35.714286  76.677846  68.584234
# 4      41.0   37.0  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162   27.0   31.0   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163   22.0   27.0   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164   19.0   22.0   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165   19.0   19.0  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166   19.0   19.0   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
imputed_df2_dum[imputed_df2_dum.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ind_5, ind_6, ind_8, ind_9, ind_10, ind_12, ind_13, ind_14, ind_15, ind_16, ind_17, ind_18, ind_19, ind_20, ind_21, ind_22, ind_23, ind_25, ind_26, ind_27, ind_28, ind_29, ind_30, ind_31, ind_32, ind_33, ind_34, ind_35, ind_36, ind_37, ind_39, ind_40, ind_41, ind_42, ind_43, ind_44, ind_45, ind_46, ind_47, ind_48, ind_49, ind_50, ind_51, ind_52, ind_53, ind_56, ind_58, ind_61, ind_62, ind_65, ind_67, ind_70, ind_71, ind_74, ind_77, ind_82, ind_83, ind_88, ind_92, ind_102, ind_116, ind_118, ind_122, ind_124, ind_128, ind_130, ind_132, ind_134, ind_136, ind_139, ind_142, ind_145, ind_147, ind_150, ind_153, ind_156, ind_164, ind_168, ind_172, ind_176, ind_179, ind_181, ind_188, ind_194, ind_212, ind_217, ind_225, ind_228, ind_234, ind_237, ind_239, ind_241, ind_243, ind_309, ind_310, ind_311, ind_313, ind_315, ind_316, ind_318, ...]
# Index: []
#
# [0 rows x 138 columns]

# %%
imputed_df2_dum
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0      19.0   17.0  100.000000  85.714286  14.285714  72.363515  60.808814
# 1      24.0   19.0  100.000000  78.571429  21.428571  74.275883  64.366798
# 2      30.0   24.0  100.000000  71.428571  28.571429  75.140402  65.915803
# 3      37.0   30.0  100.000000  64.285714  35.714286  76.677846  68.584234
# 4      41.0   37.0  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162   27.0   31.0   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163   22.0   27.0   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164   19.0   22.0   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165   19.0   19.0  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166   19.0   19.0   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
df2=imputed_df2_dum.drop({"50_target","20_target","90_target"},axis=1)

# %% [markdown]
# # Feature Selection

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["features"] = df2.columns
vif["VIF"] = [variance_inflation_factor(df2.values, i) for i in range(df2.shape[1])]

# %%
vif.sort_values(by='VIF',ascending=False)
# Out:
#               features           VIF
# 2                ind_8           inf
# 3                ind_9           inf
# 4               ind_10           inf
# 118            ind_403  2.127285e+10
# 119            ind_404  2.125312e+10
# ..                 ...           ...
# 94             ind_310  1.956135e+00
# 107            ind_340  1.735752e+00
# 125            ind_416  1.599023e+00
# 85             ind_217  1.505591e+00
# 132  labeled_90_target  1.217309e+00
#
# [135 rows x 2 columns]

# %%
vif.dtypes
# Out:
# features     object
# VIF         float64
# dtype: object

# %%
df3 = (vif.VIF <= 20.0)
vif[df3].sort_values(by='VIF',ascending=False)
# Out:
#               features        VIF
# 28              ind_36  19.466784
# 80             ind_179  19.214711
# 9               ind_16  15.760720
# 53              ind_74  15.237610
# 6               ind_13  14.317061
# 10              ind_17  14.314165
# 21              ind_29  13.828509
# 82             ind_188  13.174852
# 84             ind_212  13.135109
# 55              ind_82  12.046995
# 32              ind_41  11.540354
# 109            ind_345  11.449273
# 112            ind_351  11.369624
# 131            ind_428  11.346364
# 110            ind_347  10.681598
# 54              ind_77  10.672775
# 45              ind_56  10.370778
# 49              ind_65  10.245564
# 52              ind_71  10.080571
# 48              ind_62   9.686859
# 8               ind_15   9.596688
# 130            ind_426   8.361147
# 67             ind_134   7.932095
# 44              ind_53   7.757970
# 111            ind_349   7.361799
# 106            ind_338   6.524796
# ...

# %%
columns= []
for column in vif[df3].features:
    columns.append(column)

# %%
len(columns)
# Out:
# 57

# %%
X = df2[columns]

# %%
X.columns
# Out:
# Index(['ind_13', 'ind_14', 'ind_15', 'ind_16', 'ind_17', 'ind_18', 'ind_28',
#        'ind_29', 'ind_36', 'ind_40', 'ind_41', 'ind_53', 'ind_56', 'ind_62',
#        'ind_65', 'ind_71', 'ind_74', 'ind_77', 'ind_82', 'ind_83', 'ind_88',
#        'ind_134', 'ind_172', 'ind_176', 'ind_179', 'ind_188', 'ind_212',
#        'ind_217', 'ind_228', 'ind_237', 'ind_239', 'ind_309', 'ind_310',
#        'ind_315', 'ind_321', 'ind_324', 'ind_327', 'ind_330', 'ind_332',
#        'ind_334', 'ind_338', 'ind_340', 'ind_344', 'ind_345', 'ind_347',
#        'ind_349', 'ind_351', 'ind_352', 'ind_397', 'ind_412', 'ind_416',
#        'ind_420', 'ind_422', 'ind_424', 'ind_426', 'ind_428',
#        'labeled_90_target'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(X.corr().iloc[:,28:29], ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %%
ax = np.array([[], []])

for col in X.columns:
            
        a= X[col].corr(X["labeled_90_target"], method="pearson")
#         ax[col][0].append(a)
        print(col,a)
# Out:
# ind_13 0.06224944476797318
# ind_14 0.0538814832572439
# ind_15 0.06045511745005724
# ind_16 0.0780129728944316
# ind_17 0.09759841105038866
# ind_18 0.1265079846188658
# ind_28 0.0006359162880978494
# ind_29 -0.012550563019455988
# ind_36 0.0975068571802753
# ind_40 -0.023350509727922776
# ind_41 0.054202257847026175
# ind_53 -0.0010437548780089876
# ind_56 0.019083192348507576
# ind_62 0.031727485486725784
# ind_65 0.036947279661506544
# ind_71 0.05474347119323737
# ind_74 0.06558939929206781
# ind_77 0.09701343615777398
# ind_82 -0.05521554915953143
# ind_83 0.11584748586094798
# ind_88 -0.006644498059632758
# ind_134 0.001037075133916991
# ind_172 0.017588938528559646
# ind_176 -0.004028042805159975
# ind_179 0.02505961897391859
# ind_188 0.0012521882607015571
# ind_212 -0.021549332459673966
# ind_217 0.0001767442573806383
# ind_228 -0.03501045773253201
# ind_237 0.010736512125475824
# ind_239 0.05672014487682894
# ind_309 0.08517686721548795
# ind_310 0.06876731372615028
# ...

# %%
X
# Out:
#          ind_13  ind_14  ind_15  ind_16     ind_17   ind_18     ind_28  \
# 0     60.808814   23.80   17.62   11.73  12.060000   9.1100  66.666667
# 1     64.366798   11.45   18.16   12.22  11.326667   9.2225  66.666667
# 2     65.915803    8.75   17.86   12.28  10.973333   9.3125  66.666667
# 3     68.584234    7.80   14.76   12.61  10.426667   9.4150  66.666667
# 4     76.455495   14.90   11.92   14.25  11.406667   9.8925  66.666667
# ...         ...     ...     ...     ...        ...      ...        ...
# 6162  32.362582    9.70    9.38   13.66  15.100000  16.2175 -66.666667
# 6163  32.914628    7.65    8.84   11.79  14.753333  16.1175 -66.666667
# 6164  43.550592    8.95    9.06   10.30  14.613333  16.3125  66.666667
# 6165  54.130755   13.55   10.36   10.55  13.606667  16.4200  66.666667
# 6166  45.524973   11.45   10.16    9.68  13.020000  16.4500 -66.666667
#
#           ind_29      ind_36  ind_40  ...  ind_352    ind_397   ind_412  \
# ...

# %%
X.columns
# Out:
# Index(['ind_13', 'ind_14', 'ind_15', 'ind_16', 'ind_17', 'ind_18', 'ind_28',
#        'ind_29', 'ind_36', 'ind_40', 'ind_41', 'ind_53', 'ind_56', 'ind_62',
#        'ind_65', 'ind_71', 'ind_74', 'ind_77', 'ind_82', 'ind_83', 'ind_88',
#        'ind_134', 'ind_172', 'ind_176', 'ind_179', 'ind_188', 'ind_212',
#        'ind_217', 'ind_228', 'ind_237', 'ind_239', 'ind_309', 'ind_310',
#        'ind_315', 'ind_321', 'ind_324', 'ind_327', 'ind_330', 'ind_332',
#        'ind_334', 'ind_338', 'ind_340', 'ind_344', 'ind_345', 'ind_347',
#        'ind_349', 'ind_351', 'ind_352', 'ind_397', 'ind_412', 'ind_416',
#        'ind_420', 'ind_422', 'ind_424', 'ind_426', 'ind_428',
#        'labeled_90_target'],
#       dtype='object')

# %%
y=X["labeled_90_target"]
X=X.drop(["labeled_90_target"],axis=1).astype('float64')

# %%
y_compared=df2["labeled_90_target"]
X_compared=df2.drop(["labeled_90_target"],axis=1).astype('float64')

# %%
X.shape
# Out:
# (6167, 56)

# %%
X_compared.shape
# Out:
# (6167, 134)

# %%
# pd.crosstab([df["90_target"]],df["reason"],normalize='index').style.background_gradient(cmap="summer_r")

# %%
    from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,shuffle=False, test_size=0.30,random_state=42)
X_train_compared, X_test_compared, y_train_compared, y_test_compared = train_test_split(X_compared, y_compared,shuffle=False, test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Algorithms

# %% [markdown]
# # Gaussian Naive Bayes

# %%
gnb = GaussianNB()
gnb_model = gnb.fit(X_train_scaled, y_train)
gnb_model
# Out:
# GaussianNB()

# %%
y_pred = gnb_model.predict(X_test_scaled)
accuracy_score(y_test, y_pred)
# Out:
# 0.21339816315505133

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.58      0.39      0.47       995
#          2.0       0.00      0.00      0.00         0
#          3.0       0.33      0.00      0.01       856
#
#     accuracy                           0.21      1851
#    macro avg       0.31      0.13      0.16      1851
# weighted avg       0.47      0.21      0.26      1851

# %% [markdown]
# # MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
mnb_model = MultinomialNB().fit(X_train_scaled,y_train)
mnb_model.class_count_
# Out:
# array([1526., 1221., 1569.])

# %%
y_pred = mnb_model.predict(X_test_scaled)

# %%
y_pred[:-200]
# Out:
# array([1., 1., 1., ..., 2., 2., 3.])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.66      0.54      0.60      1210
#          2.0       0.00      0.00      0.00       316
#          3.0       0.16      0.41      0.23       325
#
#     accuracy                           0.43      1851
#    macro avg       0.27      0.32      0.27      1851
# weighted avg       0.46      0.43      0.43      1851

# %%
def tuning(model,params):
    
    cart_cv=GridSearchCV(model,params,cv=10,n_jobs=-1,verbose=2)
    cart_cv_model=cart_cv.fit(X_train_scaled,y_train)
    print('\033[1m'+ "En iyi parametreler: "'\033[0m'+str(cart_cv_model.best_params_))

# %%
mnb_params={"alpha":[0.01,0.1,1,10]}

# %%
tuning(mnb_model,mnb_params)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.6s
# En iyi parametreler: {'alpha': 1}
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    4.0s finished

# %%
mnb_tuned = MultinomialNB(alpha=1).fit(X_train_scaled,y_train)
y_pred =mnb_tuned.predict(X_test_scaled)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.66      0.54      0.60      1210
#          2.0       0.00      0.00      0.00       316
#          3.0       0.16      0.41      0.23       325
#
#     accuracy                           0.43      1851
#    macro avg       0.27      0.32      0.27      1851
# weighted avg       0.46      0.43      0.43      1851

# %% [markdown]
# # BernoulliNB

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB().fit(X_train_scaled,y_train)
y_pred = bnb.predict(X_test_scaled)
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.57      0.69      1525
#          2.0       0.00      0.00      0.00       246
#          3.0       0.05      0.56      0.10        80
#
#     accuracy                           0.50      1851
#    macro avg       0.31      0.38      0.26      1851
# weighted avg       0.73      0.50      0.58      1851

# %%
modeller=[mnb_tuned,bnb,gnb_model]
sonuc=[]
sonuclar=pd.DataFrame(columns=["Modeller","accuracy"])
for model in modeller:
    isimler=model.__class__.__name__
    y_pred=model.predict(X_test_scaled)
    dogruluk = accuracy_score(y_test, y_pred)
    sonuc=pd.DataFrame([[isimler,dogruluk]],columns=["Modeller","accuracy"])
    sonuclar=sonuclar.append(sonuc)
print(sonuclar)
#     print(isimler+"  accuracy: {:.4%}".format(dogruluk))
colors = ['r', 'g', "b"]

sns.barplot(x="accuracy",y='Modeller',data=sonuclar,color='r')

plt.xlabel('accuracy %')
plt.title("modellerin doğruluk oranları")
# Out:
#         Modeller  accuracy
# 0  MultinomialNB  0.428417
# 0    BernoulliNB  0.496488
# 0     GaussianNB  0.213398
# Text(0.5, 1.0, 'modellerin doğruluk oranları')

# %%
#Confusion matrix function


from sklearn.metrics import confusion_matrix

def conf_mtrx(y_test, y_pred):
    
    cm = confusion_matrix(y_test,y_pred)
    
    f, ax = plt.subplots(figsize =(5,5))
    cm = confusion_matrix(y_test,y_pred)

    sns.heatmap(cm,annot = True, linewidths=0.5, linecolor="red",fmt = ".0f",ax=ax)
    plt.xlabel("predicted y values")
    plt.ylabel("real y values")
    plt.title("\nConfusion Matrix")
    plt.show()

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

def rc_recis_scres(y_test, y_pred, algorithm_name):
    rs=recall_score(y_test, y_pred) 
    ps=precision_score(y_test, y_pred) 


    print("Recall Score of ", algorithm_name, " : ",rs)
    print("Precision Score of ", algorithm_name, " : ",ps)
    print()

# %% [markdown]
# # veri dengesizliğinden dolayı

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

gnb.fit(X_train,y_train.values.ravel())
alg_name="GaussianNB"  

y_pred = gnb.predict(X_test)

print(alg_name," ALGORITHM:") 
conf_mtrx(y_test, y_pred)
# Out:
# GaussianNB  ALGORITHM:

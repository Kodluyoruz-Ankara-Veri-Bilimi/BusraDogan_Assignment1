# %% [markdown]
# # BusraDoganHW_Data_Set

# %% [markdown]
# ## Importing Libraries

# %%
# LIBRARIES                         
import pandas as pd
import numpy as np

import collections
import math

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler


#Machine learning algorithms libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB,GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVC,SVR
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


from warnings import filterwarnings
filterwarnings('ignore')

# %%
# import statsmodels.api as sm
from scipy import stats
# import scipy.stats
from scipy.stats import shapiro
from scipy.stats import levene

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.23.1.

# %%
import scipy
scipy.version.full_version
# Out:
# '1.5.0'

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.7

# %%
class datasetAnalysis:

    
    def __init__(self,data,target):
        self.data=data
        self.target=target

    def datasetInfo1(self):
        
        print( '\033[1m'+ "\n Shape of Dataset :" + '\033[0m',self.data.shape)
        print(self.data.info())
        print(self.data.describe())
        print( '\033[1m'+ "\n General Information of Dataset\n" + '\033[0m',self.data.head())
        print('\033[1m'+ " \n Showing Missing Values\n" + '\033[0m')
        print(self.data.isnull().sum())
        
        
    def datasetInfo2(self):
        print(self.data.columns)
        print("\n" , '\033[1m'+ "Target Counts\n" + '\033[0m', self.data[target].value_counts(),"\n")
        
        for i in self.data.columns:
            print(self.data[i].value_counts().head(7),"\n")


class PreVisulation:
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    def __init__(self,data,feature):
#         self.data=data
#         self.target=target
        self.feature=feature
        self.data=data

    def vis1(self):
        
    #target distribution
        print(data[target].value_counts())
        sns.set(style="darkgrid")
        ax= sns.countplot(y="reason", hue=target, data=data)
        
#         data[target].value_counts().plot("barh")
    def vis2(self): 
        
        data[feature].plot.hist(bins = 20,figsize=(15,7.5))
        
        
        
    def vis3(self): 
        
        
        for i in range(len(self.data.dtypes)):

               
            
            if (self.data.dtypes[i] != "object" and self.data.iloc[:,i].notna().all()):

                f,axes = newplt.subplots(1,1)
                sns.distplot(self.data.iloc[:,i],kde_kws=dict(linewidth=5),bins = 20)
                
            elif (self.data.dtypes[i] == "object" and self.data.iloc[:,i].notna().all()):
                f,axes = newplt.subplots(1,1)
                sns.countplot(self.data.iloc[:,i],data=self.data)
        
        # Verinin boxplot gösterimi
        newplt.figure()
        sns.boxplot(data=self.data)

# %%
class preprocess():
    from sklearn.impute import SimpleImputer
    
    def __init__(self, data):
        self.data=data
    
    def missingvalues(self):
        # Imputation
#         if self.data.col.dtypes == 'object':
                        
#             self.data[col] = self.data[col].replace(np.nan, "Other")
#             print(self.data.isna().sum())
#         else:
        my_imputer = SimpleImputer()
        imputed_df2_dum = pd.DataFrame(my_imputer.fit_transform(self.data))
        imputed_df2_dum.columns = self.data.columns
        self.data=imputed_df2_dum.copy()
    
    def dummies(self):
        df=data
    
        df_num = df.select_dtypes(exclude=[np.number])
        df_num.columns
        a=df_num.columns
        dff=self.data.copy()
    #     s = (df2.dtypes == 'object')
    #     object_cols = list(s[s].index)
        for i in a:
            if self.data[i].value_counts().count() <= 6:


                df2_dum = pd.get_dummies(self.data[i],columns= i, prefix= i) #prefix_sep = '_'
                print(list(df2_dum.columns))
                dff = pd.concat([dff, df2_dum], axis=1).drop(i,axis=1)
                print(list(dff.columns))
        self.data=dff.copy()        
        return self.data

# %%
class process():
    global train
    global test
    
    
    def __init__(self,X,y,size):
     
        self.size=size
        self.X=X
        self.y=y
    
    def split(self):
        
        # train-test spit
        X_train, X_test, y_train, y_test = train_test_split(self.X, self.y, test_size=self.size,stratify=df[target],shuffle=True,random_state=42)#shuffle=False,
        

        print("\n", '\033[1m'+ " X_train,X_test Info" + '\033[0m')
        print(X_train.shape,X_test.shape)
        print("\n", '\033[1m'+ " X_train,y_test Info" + '\033[0m')
        print(y_train.shape,y_test.shape)
        return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Reading The Dataset

# %%
#read data 
from pandas import read_excel
df = pd.read_excel('HW_Data_Set.xlsx')

# %% [markdown]
# # Description of Variables¶

# %%
target='90_target'
data=datasetAnalysis(df,target)
data.datasetInfo1()
# Out:
#  Shape of Dataset : (6167, 136)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6167 entries, 0 to 6166
# Columns: 136 entries, ind_5 to 90_target
# dtypes: float64(88), int64(45), object(3)
# memory usage: 6.4+ MB
# None
#              ind_5        ind_6        ind_8        ind_9       ind_10  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean     -0.803146    -0.803470    48.388890    48.289282     0.099609
# std      23.624403    23.624144    36.388526    36.478009    60.414625
# min    -131.000000  -131.000000     0.000000     0.000000  -100.000000
# 25%     -14.000000   -14.000000    14.285714    14.285714   -50.000000
# 50%       0.000000     0.000000    50.000000    50.000000     0.000000
# 75%      13.000000    13.000000    85.714286    85.714286    57.142857
# max      76.000000    76.000000   100.000000   100.000000   100.000000
#
#             ind_12       ind_13       ind_14       ind_15       ind_16  ...  \
# ...

# %%
data=df.copy()
data.head(5)
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target
# ...

# %%
data.shape
# Out:
# (6167, 136)

# %%
df= data.copy()
df = df.dropna(how="any")
df.shape
# Out:
# (6167, 136)

# %%
df.select_dtypes(include=['object'])
# Out:
#      ind_109 ind_420 ind_422
# 0      GREEN    -152    -353
# 1      GREEN    -158    -359
# 2      GREEN    -160    -362
# 3      GREEN    -166    -367
# 4      GREEN    -186    -388
# ...      ...     ...     ...
# 6162     RED     -11    -270
# 6163     RED     -12    -271
# 6164   GREEN     -21    -280
# 6165   GREEN     -33    -292
# 6166   GREEN     -28    -288
#
# [6167 rows x 3 columns]

# %%
data.ind_109.describe()
# Out:
# count      6167
# unique        2
# top       GREEN
# freq       3132
# Name: ind_109, dtype: object

# %%
data["ind_420"].describe()
# Out:
# count     6167
# unique     582
# top          ?
# freq      1041
# Name: ind_420, dtype: object

# %%
target='90_target'
df=datasetAnalysis(data,target)
df.datasetInfo1()
# Out:
#  Shape of Dataset : (6167, 136)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6167 entries, 0 to 6166
# Columns: 136 entries, ind_5 to 90_target
# dtypes: float64(88), int64(45), object(3)
# memory usage: 6.4+ MB
# None
#              ind_5        ind_6        ind_8        ind_9       ind_10  \
# count  6167.000000  6167.000000  6167.000000  6167.000000  6167.000000
# mean     -0.803146    -0.803470    48.388890    48.289282     0.099609
# std      23.624403    23.624144    36.388526    36.478009    60.414625
# min    -131.000000  -131.000000     0.000000     0.000000  -100.000000
# 25%     -14.000000   -14.000000    14.285714    14.285714   -50.000000
# 50%       0.000000     0.000000    50.000000    50.000000     0.000000
# 75%      13.000000    13.000000    85.714286    85.714286    57.142857
# max      76.000000    76.000000   100.000000   100.000000   100.000000
#
#             ind_12       ind_13       ind_14       ind_15       ind_16  ...  \
# ...

# %%
data.corr().iloc[:,130:133]
# Out:
#            20_target  50_target  90_target
# ind_5       0.060969   0.068989   0.060428
# ind_6       0.062101   0.069652   0.061560
# ind_8      -0.004126   0.006984  -0.006650
# ind_9      -0.031316  -0.004053   0.012093
# ind_10      0.016423   0.006654  -0.011307
# ...              ...        ...        ...
# ind_426     0.019599   0.009063  -0.002519
# ind_428     0.047041   0.052418   0.043563
# 20_target   1.000000   0.384076   0.355950
# 50_target   0.384076   1.000000   0.940916
# 90_target   0.355950   0.940916   1.000000
#
# [133 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize=(5, 30))
sns.heatmap(data.corr().iloc[:,130:133], ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %% [markdown]
# # Visualization

# %%
sns.violinplot(x ='90_target', y ='ind_412', data = data,color='yellow')

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[["20_target", "50_target","90_target"]]
boxplot_df.boxplot()
plt.show()
# box ile tüm features bak ve outlier durumunu incele

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[[ 'ind_239', 'ind_309', 'ind_310', 'ind_324', 'ind_327', 'ind_332', 'ind_344',   'ind_412', 'ind_416']]
boxplot_df.boxplot()
plt.show()

# %%
plt.figure(figsize=(10,8))
boxplot_df = data[[ 'ind_239', 'ind_309', 'ind_310', 'ind_324',  'ind_344',   'ind_412']]
boxplot_df.boxplot()
plt.show()

# %%
sns.distplot(data["90_target"])
plt.show()

# %%
fig, ax=plt.subplots(figsize=(7,7))
sns.scatterplot(x="ind_310", y= "ind_412",hue= "90_target",data=data)

# %%
data["ind_420"].describe()
# Out:
# count     6167
# unique     582
# top          ?
# freq      1041
# Name: ind_420, dtype: object

# %%
# dff=data.drop(labels=["ind_420","ind_422"],axis=1,inplace=True)
df2=data.replace('?',np.nan)

# %%
df2.shape
# Out:
# (6167, 136)

# %%
df2.loc[df2['ind_420'].isnull(),'ind_420':]
# Out:
#       ind_420  ind_422   ind_424   ind_426   ind_428  20_target  50_target  \
# 57        NaN      NaN  0.971429  0.178117  0.284799 -15.116561  35.579963
# 58        NaN      NaN  0.983333  0.236908  0.305455 -15.119579  35.587067
# 59        NaN      NaN  1.000000  0.302326  0.319073 -15.121214  35.590915
# 60        NaN      NaN  1.000000  0.390519  0.369295 -15.131401  35.614892
# 61        NaN      NaN  0.870000  0.398104  0.327241 -15.121465  35.591507
# ...       ...      ...       ...       ...       ...        ...        ...
# 1791      NaN      NaN  1.000000  0.858397  0.705635 -15.510827 -36.507950
# 1792      NaN      NaN  0.000000  0.697733  0.682281 -15.499005 -36.480126
# 1793      NaN      NaN  0.000000  0.596639  0.680818 -15.508689 -36.502918
# 1794      NaN      NaN  1.000000  0.600666  0.690900 -15.507054 -36.499070
# 1795      NaN      NaN  0.245614  0.417857  0.663086  15.494604 -36.469765
#
#       90_target
# 57    36.950719
# 58    36.958096
# ...

# %% [markdown]
# # Categorical Variables to Numerical

# %%
dfImputer=preprocess(df2)

aa=dfImputer.dummies()
# Out:
# ['ind_109_GREEN', 'ind_109_RED']
# ...

# %%
aa.reset_index(drop=True, inplace=True)

dff=aa.copy()

# %%
dff
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %% [markdown]
# # Solve NaN Values with Imputer

# %%
from sklearn.impute import SimpleImputer

# Imputation
my_imputer = SimpleImputer()
imputed_df2_dum = pd.DataFrame(my_imputer.fit_transform(dff))
imputed_df2_dum.columns = dff.columns

# %%
imputed_df2_dum
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0      19.0   17.0  100.000000  85.714286  14.285714  72.363515  60.808814
# 1      24.0   19.0  100.000000  78.571429  21.428571  74.275883  64.366798
# 2      30.0   24.0  100.000000  71.428571  28.571429  75.140402  65.915803
# 3      37.0   30.0  100.000000  64.285714  35.714286  76.677846  68.584234
# 4      41.0   37.0  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162   27.0   31.0   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163   22.0   27.0   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164   19.0   22.0   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165   19.0   19.0  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166   19.0   19.0   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
imputed_df2_dum[imputed_df2_dum.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ind_5, ind_6, ind_8, ind_9, ind_10, ind_12, ind_13, ind_14, ind_15, ind_16, ind_17, ind_18, ind_19, ind_20, ind_21, ind_22, ind_23, ind_25, ind_26, ind_27, ind_28, ind_29, ind_30, ind_31, ind_32, ind_33, ind_34, ind_35, ind_36, ind_37, ind_39, ind_40, ind_41, ind_42, ind_43, ind_44, ind_45, ind_46, ind_47, ind_48, ind_49, ind_50, ind_51, ind_52, ind_53, ind_56, ind_58, ind_61, ind_62, ind_65, ind_67, ind_70, ind_71, ind_74, ind_77, ind_82, ind_83, ind_88, ind_92, ind_102, ind_116, ind_118, ind_122, ind_124, ind_128, ind_130, ind_132, ind_134, ind_136, ind_139, ind_142, ind_145, ind_147, ind_150, ind_153, ind_156, ind_164, ind_168, ind_172, ind_176, ind_179, ind_181, ind_188, ind_194, ind_212, ind_217, ind_225, ind_228, ind_234, ind_237, ind_239, ind_241, ind_243, ind_309, ind_310, ind_311, ind_313, ind_315, ind_316, ind_318, ...]
# Index: []
#
# [0 rows x 137 columns]

# %%
imputed_df2_dum
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0      19.0   17.0  100.000000  85.714286  14.285714  72.363515  60.808814
# 1      24.0   19.0  100.000000  78.571429  21.428571  74.275883  64.366798
# 2      30.0   24.0  100.000000  71.428571  28.571429  75.140402  65.915803
# 3      37.0   30.0  100.000000  64.285714  35.714286  76.677846  68.584234
# 4      41.0   37.0  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162   27.0   31.0   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163   22.0   27.0   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164   19.0   22.0   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165   19.0   19.0  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166   19.0   19.0   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
df2=imputed_df2_dum.drop({"50_target","20_target"},axis=1)

# %% [markdown]
# # Feature Selection

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["features"] = df2.columns
vif["VIF"] = [variance_inflation_factor(df2.values, i) for i in range(df2.shape[1])]

# %%
vif.sort_values(by='VIF',ascending=False)
# Out:
#       features           VIF
# 2        ind_8           inf
# 3        ind_9           inf
# 4       ind_10           inf
# 119    ind_404  2.126054e+10
# 118    ind_403  2.124329e+10
# ..         ...           ...
# 94     ind_310  1.951110e+00
# 107    ind_340  1.736275e+00
# 125    ind_416  1.600726e+00
# 85     ind_217  1.505649e+00
# 132  90_target  1.216595e+00
#
# [135 rows x 2 columns]

# %%
vif.dtypes
# Out:
# features     object
# VIF         float64
# dtype: object

# %%
df3 = (vif.VIF <= 5.0)
vif[df3].sort_values(by='VIF',ascending=False)
# Out:
#       features       VIF
# 103    ind_330  4.845678
# 113    ind_352  4.765259
# 116    ind_397  4.738124
# 56      ind_83  4.576081
# 31      ind_40  4.401399
# 78     ind_172  4.284349
# 108    ind_344  4.272092
# 128    ind_422  4.240294
# 79     ind_176  4.117172
# 127    ind_420  3.851399
# 129    ind_424  3.638177
# 104    ind_332  3.412330
# 100    ind_321  3.174583
# 89     ind_237  2.927375
# 97     ind_315  2.847469
# 11      ind_18  2.816232
# 20      ind_28  2.807224
# 101    ind_324  2.728385
# 123    ind_412  2.459948
# 90     ind_239  2.438598
# 102    ind_327  2.436759
# 57      ind_88  2.245152
# 87     ind_228  2.206583
# 93     ind_309  2.058609
# 94     ind_310  1.951110
# 107    ind_340  1.736275
# 125    ind_416  1.600726
# 85     ind_217  1.505649
# 132  90_target  1.216595

# %%
columns= []
for column in vif[df3].features:
    columns.append(column)

# %%
len(columns)
# Out:
# 29

# %%
X = df2[columns]

# %%
X.columns
# Out:
# Index(['ind_18', 'ind_28', 'ind_40', 'ind_83', 'ind_88', 'ind_172', 'ind_176',
#        'ind_217', 'ind_228', 'ind_237', 'ind_239', 'ind_309', 'ind_310',
#        'ind_315', 'ind_321', 'ind_324', 'ind_327', 'ind_330', 'ind_332',
#        'ind_340', 'ind_344', 'ind_352', 'ind_397', 'ind_412', 'ind_416',
#        'ind_420', 'ind_422', 'ind_424', '90_target'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(X.corr().iloc[:,28:29], ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# %%
ax = np.array([[], []])

for col in X.columns:
            
        a= X[col].corr(X["90_target"], method="pearson")
#         ax[col][0].append(a)
        print(col,a)
# Out:
# ind_18 0.14087679463003316
# ind_28 -0.0012406929299725337
# ind_40 -0.009347298191433687
# ind_83 0.05120699730222782
# ind_88 -0.000599126136094975
# ind_172 0.012618145598907785
# ind_176 -0.008955701157372587
# ind_217 -0.01220497988421671
# ind_228 -0.05656080655050421
# ind_237 -0.017967284160564072
# ind_239 0.06360002274237458
# ind_309 0.057078530277021415
# ind_310 0.07055762823300699
# ind_315 -0.0499020431689436
# ind_321 0.05152817129498273
# ind_324 -0.10370697957037796
# ind_327 0.020616770188609374
# ind_330 -0.09381088997276177
# ind_332 0.11500150512229602
# ind_340 -0.025615695399616886
# ind_344 0.016062906654213588
# ind_352 0.00716343998400049
# ind_397 -0.0064420837438283465
# ind_412 0.12426474991040602
# ind_416 0.049614671603196346
# ind_420 -0.022487180157435654
# ind_422 0.002322885413522382
# ind_424 -0.007688698866314808
# 90_target 1.0

# %%
dff
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
y=X[["90_target"]]
X=X[["ind_18","ind_83","ind_228","ind_239","ind_310","ind_321","ind_324","ind_330","ind_332","ind_412"]]

# %%
# y=dff[["90_target"]]
# X=dff[["ind_18","ind_83","ind_228","ind_239","ind_310","ind_321","ind_324","ind_330","ind_332","ind_412"]]

# %%
# pd.crosstab([df["90_target"]],df["reason"],normalize='index').style.background_gradient(cmap="summer_r")

# %%
    from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,shuffle=False, test_size=0.30,random_state=42)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.ensemble import RandomForestRegressor

pca=PCA() 
X_reduced_train=pca.fit_transform(scale(X_train))
lm=RandomForestRegressor()
pcr_model=lm.fit(X_reduced_train,y_train)
np.cumsum(np.round(pca.explained_variance_ratio_,decimals=4)*100)
# Out:
# array([ 27.48,  42.83,  55.99,  67.26,  75.98,  82.93,  88.83,  93.77,
#         97.9 , 100.  ])

# %%
x_reduced_train=pca.fit_transform(scale(X_train))
x_reduced_train[0:1,:]
# Out:
# array([[ 0.04041732, -1.14036044,  0.27420758,  2.3180763 ,  0.6260211 ,
#         -0.81000226,  0.67327198, -0.20553909, -0.28015849, -0.04375022]])

# %%
pca=PCA(n_components=9)
x_reduced_train=pca.fit_transform(scale(X_train))
X_reduced_test=pca.transform(scale(X_test))

# %%
def pca_fon(X, threshold):
    pca = PCA()
    X_pca = pca.fit_transform(X)
    arr = np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4)*100)
    num_var = sum((arr < threshold*100)) + 1 
    print('pca sonrası değişken sayısı: ',num_var)
    X_pcad = pd.DataFrame(X_pca[:,0:num_var], index = X.index)
    return X_pcad

pca_fon(X_train, 0.5).head(3)
# Out:
# pca sonrası değişken sayısı:  1
#            0
# 0 -18.796243
# 1 -18.671528
# 2 -18.569840

# %%
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import confusion_matrix


    
def ML_Algorithms(X_train, X_test, y_train, y_test, alg_name, model):
    from sklearn.metrics import roc_auc_score,roc_curve

    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)    
    print("*****",alg_name," ALGORITHM:") 

    print("Score for ", alg_name," train set:"  ,  model.score(X_train,y_train))
    print("Score for ", alg_name, " test set: ", model.score(X_test,y_test))
    

    return model    
    

    
def tuning(model,params):
    
    cart_cv=GridSearchCV(model,params,cv=10,n_jobs=-1,verbose=2)
    cart_cv_model=cart_cv.fit(X_train,y_train)
    print('\033[1m'+ "En iyi parametreler: "'\033[0m'+str(cart_cv_model.best_params_))

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
cart_model=DecisionTreeRegressor()
cart_model.fit(x_reduced_train,y_train)
y_pred=cart_model.predict(X_test)

# %%
cart_grid={"min_samples_leaf":[10,15,20],
          "min_samples_split":range(10,50),
          "max_leaf_nodes":range(4,8)}

# %%
cart_cv=GridSearchCV(cart_model,cart_grid,cv=10,n_jobs=-1,verbose=2)
cart_cv_model=cart_cv.fit(x_reduced_train,y_train)
# Verbose ile de işlem sırasında ekrana ayrın
# Out:
# Fitting 10 folds for each of 480 candidates, totalling 4800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 2296 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 4560 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 4800 out of 4800 | elapsed:   21.8s finished

# %%
print(" en iyi parametreler:"+str(cart_cv_model.best_params_))
# dept fazla, features az olursa aynı feaures tekrar tekrar kullanılır. bu feature importance nin çok yüksek olması olabilir
# Out:
#  en iyi parametreler:{'max_leaf_nodes': 4, 'min_samples_leaf': 10, 'min_samples_split': 45}

# %%
cart=tree.DecisionTreeRegressor(max_leaf_nodes=4,min_samples_split=41,min_samples_leaf=10)
dt_tuned=cart.fit(x_reduced_train,y_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score

y_pred=dt_tuned.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 37.213910931616624

# %%
plt.figure(figsize=(15,15),dpi  = 100)
tree.plot_tree(dt_tuned,feature_names= X_train.columns,rounded = True,
              filled = True,
              impurity = True);

# %% [markdown]
# # RANDOM FOREST

# %%
rf_params={"max_depth":[2,5,8,10,20,30],
          "max_features":[2,5,8],
          "n_estimators":[10,50,100],
          "min_samples_split":[5,10]}

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score

rf_model=RandomForestRegressor()
cart_cv=GridSearchCV(rf_model,rf_params,cv=10,n_jobs=-1,verbose=2)
cart_cv_model=cart_cv.fit(x_reduced_train,y_train))
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed:  1.4min finished

# %%
print(" en iyi parametreler:"+str(cart_cv_model.best_params_))
# Out:
#  en iyi parametreler:{'max_depth': 5, 'max_features': 2, 'min_samples_split': 5, 'n_estimators': 50}

# %%
cart=RandomForestRegressor(max_depth=5,max_features=3,n_estimators=50,min_samples_split=5)
rf_tuned=cart.fit(x_reduced_train,y_train)

# %%
plt.figure(figsize=(15,15),dpi  = 100)
tree.plot_tree(rf_tuned,feature_names= X_train.columns,rounded = True,
              filled = True,
              impurity = True);

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((4316, 10), (1851, 10), (4316, 1), (1851, 1))

# %%
y_pred.shape
# Out:
# (1851,)

# %%
y_pred=rf_tuned.predict(X_reduced_test)
cross_val_score(rf_tuned, X_train, y_train, cv = 10, scoring = "r2").mean()
# Out:
# -0.12014731092783855

# %%
print(np.sqrt(-cross_val_score(rf_tuned,  X_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean())
np.sqrt(-cross_val_score(rf_tuned, X_test,  y_test, cv = 10,  scoring = "neg_mean_squared_error")).mean()
# Out:
# 37.75299367763163
# 38.25863026399145

# %% [markdown]
# # neural network

# %%
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.neural_network import MLPRegressor
mlp_model=MLPRegressor(hidden_layer_sizes=(100,20))
mlp_model.fit(x_reduced_train,y_train)

mlp_model.n_layers_
mlp_model.hidden_layer_sizes
y_pred=mlp_model.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 69.34031004096458

# %%
mlp_params={'alpha':[0.1,0.01,0.02,0.005],
           'hidden_layer_sizes':[(20,20),(100,50,150),(300,200,150)],
           'activation':['relu','logistic']}
mlp_cv_model=GridSearchCV(mlp_model,mlp_params,cv=10,n_jobs=-1)
mlp_cv_model.fit(x_reduced_train,y_train)
mlp_cv_model.best_params_
# Out:
# {'activation': 'logistic', 'alpha': 0.1, 'hidden_layer_sizes': (20, 20)}

# %%
mlp_tuned=MLPRegressor(alpha=0.1,activation= 'logistic',hidden_layer_sizes=(20, 20))

# %%
mlp_tuned.fit(x_reduced_train,y_train)
y_pred=mlp_tuned.predict(X_reduced_test)

# %%
y_pred=rf_tuned.predict(X_test)
print(cross_val_score(mlp_model, X_train, y_train, cv = 10, scoring = "r2").mean())
# Out:
# -0.3347889647442865

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score

k_range = list(range(1,10))
scores = []
for k in k_range:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)

    scores.append(np.sqrt(mean_squared_error(y_test,y_pred)))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model=KNeighborsRegressor().fit(x_reduced_train,y_train)

# %%
y_pred=knn_model.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# x_reduced_train X_reduced_test
# Out:
# 46.97953426055636

# %%
np.sqrt(-cross_val_score(knn_model,  x_reduced_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 46.328861315018955

# %%
knn_params={"n_neighbors":np.arange(1,10,1),
            "metric":["minkowski","euclidean","manhattan"],
            "weights":['uniform','distance']
           }

# %%
tuning(knn_model,knn_params)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.3s
# En iyi parametreler: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 525 out of 540 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 540 out of 540 | elapsed:    3.9s finished

# %%
knn_tuned=KNeighborsRegressor(metric='manhattan',n_neighbors=9,weights='uniform').fit(x_reduced_train,y_train)

# %%
y_pred=knn_tuned.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# x_reduced_train X_reduced_test
# Out:
# 43.81600133020154

# %%
np.sqrt(-cross_val_score(knn_tuned,  x_reduced_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 44.26207382125348

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbm_model=GradientBoostingRegressor().fit(x_reduced_train,y_train)
gbm_model.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'ls',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'presort': 'deprecated',
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
y_pred=gbm_model.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 37.675202604483644

# %%
np.sqrt(-cross_val_score(gbm_model,  x_reduced_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 39.41528355920628

# %%
gbm_params={"learning_rate":[0.01,0.1],
           "n_estimators":[10,20],         
            "max_depth": [3,5],
             "min_samples_split": [5,10]}

# %%
tuning(gbm_model,gbm_params)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    4.4s
# En iyi parametreler: {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 10}
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:    9.1s finished

# %%
gbm_tuned=GradientBoostingRegressor(learning_rate=0.01,max_depth=3,min_samples_split=5,n_estimators=10).fit(x_reduced_train,y_train)

# %%
y_pred=gbm_tuned.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 35.8813282858094

# %%
np.sqrt(-cross_val_score(gbm_tuned,  x_reduced_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 37.41568227429515

# %% [markdown]
# # SVR

# %%
svr_model=SVR(C=1.2, kernel='poly', degree=2).fit(x_reduced_train,y_train)
y_pred=svr_model.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 58.769806387808714

# %%
svc_params = {"C" : [  0.1, 1, ],
                 "gamma" : [ 1, 5, ],
                 "kernel":['rbf','linear']}

# %%
tuning(svc_model,svc_params)

# %%
svr_tuned=SVR(C=1.2, kernel='poly', degree=2).fit(x_reduced_train,y_train)
y_pred=svr_tuned.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 58.769806387808714

# %%
np.sqrt(-cross_val_score(svr_tuned,  x_reduced_train, y_train,cv = 10, scoring = "neg_mean_squared_error")).mean()
# Out:
# 46.89070358607782

# %%
modeller=[gbm_tuned,knn_tuned,mlp_tuned,svr_tuned,rf_tuned,dt_tuned]
sonuc=[]
sonuclar=pd.DataFrame(columns=["Modeller","MSE"])
for model in modeller:
    isimler=model.__class__.__name__
    y_pred=model.predict(X_reduced_test)
    dogruluk=np.sqrt(mean_squared_error(y_test,y_pred))
    sonuc=pd.DataFrame([[isimler,dogruluk]],columns=["Modeller","MSE"])
    sonuclar=sonuclar.append(sonuc)
print(sonuclar)
#     print(isimler+"  accuracy: {:.4%}".format(dogruluk))
# colors = ["purple", "green", "orange"]

sns.barplot(x="MSE",y='Modeller',data=sonuclar,color='r')

plt.xlabel('error %')
plt.title("modellerin doğruluk oranları")
# Out:
#                     Modeller        MSE
# 0  GradientBoostingRegressor  35.881328
# 0        KNeighborsRegressor  43.816001
# 0               MLPRegressor  36.032636
# 0                        SVR  58.769806
# 0      RandomForestRegressor  36.123050
# 0      DecisionTreeRegressor  37.213911
# Text(0.5, 1.0, 'modellerin doğruluk oranları')

# %% [markdown]
# # STATISTIC

# %% [markdown]
# 3- Ortalamalarını karşılaştırcağımız için T TEST i yapıyoruz. (loan normal dağılımdan gelmeli o yüzden shapiro testi yapılmalı)
#
# 1- Shapiro da features bakıyoruz normal davranıştan mı geliyor
#
# 2- Equle varyans bakmamız lazım t test içinde bir parametre çünkü. Levene bad ve good arasına baktım

# %%
df = X.copy()

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.dtypes
# Out:
# ind_18     float64
# ind_83     float64
# ind_228    float64
# ind_239    float64
# ind_310    float64
# ind_321    float64
# ind_324    float64
# ind_330    float64
# ind_332    float64
# ind_412    float64
# dtype: object

# %% [markdown]
# # Normallik - Shapiro Testi

# %%
for col in X.columns[:]:           #bad hariç
    if X[col].dtypes != object:
        
        stat, p = shapiro(X[col])

        print('Shapiro Statistics=%.3f, p=%.3f' % (stat, p))

        alpha = 0.05
        if p > alpha:
            print(col)
            print('\033[1m'+ col + '\033[0m','Normal dağılımdan gelmekte (Fail to Reject H0) \n')
        else:
            print('\033[1m'+ col + ":"+'\033[0m','Normal dağılımdan gelmemekte (reject H0)\n')
# Out:
# Shapiro Statistics=0.952, p=0.000
# ind_18: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.777, p=0.000
# ind_83: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.196, p=0.000
# ind_228: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.417, p=0.000
# ind_239: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.838, p=0.000
# ind_310: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.591, p=0.000
# ind_321: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.600, p=0.000
# ind_324: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.407, p=0.000
# ind_330: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.537, p=0.000
# ind_332: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.985, p=0.000
# ind_412: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.661, p=0.000
# 90_target: Normal dağılımdan gelmemekte (reject H0)

# %%
df.columns
# Out:
# Index(['ind_18', 'ind_83', 'ind_228', 'ind_239', 'ind_310', 'ind_321',
#        'ind_324', 'ind_330', 'ind_332', 'ind_412', '90_target'],
#       dtype='object')

# %%
y = X["90_target"]
X = X.drop("90_target", axis=1)

# %%
X.shape
# Out:
# (6167, 10)

# %%
from sklearn.model_selection import train_test_split,cross_val_score, cross_val_predict
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2,shuffle=False, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape

# %%
import statsmodels.api as sm

# %%
lm =sm.OLS(y_train,X_train)

# %%
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.070
# Model:                            OLS   Adj. R-squared (uncentered):              0.068
# Method:                 Least Squares   F-statistic:                              37.11
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):                    7.58e-71
# Time:                        03:24:37   Log-Likelihood:                         -24668.
# No. Observations:                4933   AIC:                                  4.936e+04
# Df Residuals:                    4923   BIC:                                  4.942e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
#0.05 ten büyükleri ele

# %%
# drop p value >0.05 olanları
X = X.drop({'ind_18', 'ind_321'}, axis=1)

# %%
X = X.drop({'ind_83', 'ind_330'}, axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2,shuffle=False, random_state=42)

# %%
X_train.shape
# Out:
# (4933, 6)

# %%
lm =sm.OLS(y_train,X_train)

# %%
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              90_target   R-squared (uncentered):                   0.069
# Model:                            OLS   Adj. R-squared (uncentered):              0.068
# Method:                 Least Squares   F-statistic:                              60.66
# Date:                Sat, 25 Jul 2020   Prob (F-statistic):                    8.20e-73
# Time:                        03:26:37   Log-Likelihood:                         -24671.
# No. Observations:                4933   AIC:                                  4.935e+04
# Df Residuals:                    4927   BIC:                                  4.939e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Hataların standard dagilimdan gelmesi gerekiyor.
# fazla outlier gozlemler bulunmakta. 
#  model dogru bir fit yapmamis. ?

# %%
influence = model.get_influence()
resid_student = influence.resid_studentized_external
(cooks, p) = influence.cooks_distance
(dffits, p) = influence.dffits
leverage = influence.hat_matrix_diag
print("Leverage v.s. Studentized Residuals")
sns.regplot(leverage, model.resid_pearson, fit_reg=False)
# Out:
# Leverage v.s. Studentized Residuals

# %%
plt.plot(model.resid)

# her daha pointteki hatalar. constant varyans var. 
# artışlı bir eğim olmasını istemeyiz

# %%
for i in X.columns:
    stats.probplot(X[i], dist="norm", plot=plt)
    plt.title(i)
    plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model = lr.fit(X_train,y_train)

# %%
y_predicted = lr.predict(X_test)

# %%
# Test Verileri Tahmin ve Hatalar
error_table=pd.DataFrame({"Predicted" : y_predicted ,
                          "Expected" : y_test, 
                          "Error" : y_test - y_predicted ,
                          "ErrorSquare" :(y_test - y_predicted)*(y_test - y_predicted) })
error_table.head(20)
# Out:
#       Predicted   Expected      Error  ErrorSquare
# 4933   0.227871 -35.996202 -36.224072  1312.183413
# 4934   0.786245 -35.993128 -36.779373  1352.722276
# 4935   0.646670 -35.993128 -36.639797  1342.474749
# 4936  -0.913707 -35.983290 -35.069584  1229.875693
# 4937  -2.673302 -35.973453 -33.300151  1108.900040
# 4938  -2.988073 -35.970994 -32.982921  1087.873075
# 4939  -3.265213  35.954701  39.219914  1538.201642
# 4940  -3.492450  35.930415  39.422865  1554.162308
# 4941  -3.230398 -35.987594 -32.757196  1073.033905
# 4942  -2.040136 -36.047540 -34.007404  1156.503510
# 4943  -0.808021 -35.990668 -35.182648  1237.818693
# 4944  -1.352909 -36.007883 -34.654974  1200.967249
# 4945  -2.518547 -36.055840 -33.537292  1124.749973
# 4946  -2.561844 -35.994050 -33.432206  1117.712379
# 4947  -3.366829 -35.952856 -32.586027  1061.849161
# 4948  -5.015812  35.866166  40.881978  1671.336111
# 4949  -4.709000  35.870777  40.579777  1646.718319
# ...

# %%
error_table.sort_values(by='ErrorSquare',ascending=True)
# Out:
#       Predicted   Expected       Error   ErrorSquare
# 5639  35.451282  35.574739    0.123457      0.015242
# 5640  35.239444  35.574124    0.334680      0.112010
# 5643  34.366869  35.562442    1.195573      1.429395
# 6012 -33.521193 -35.888300   -2.367107      5.603195
# 6011 -33.490558 -35.871392   -2.380834      5.668370
# 6015 -33.268208 -35.789313   -2.521105      6.355971
# 6018 -33.066317 -35.813291   -2.746974      7.545866
# 6013 -32.993372 -35.864629   -2.871257      8.244117
# 6010 -32.894339 -35.860325   -2.965986      8.797074
# 5638  38.746993  35.565209   -3.181785     10.123753
# 6016 -32.592355 -35.785931   -3.193576     10.198929
# 6017 -32.395773 -35.803146   -3.407373     11.610190
# 6014 -32.376232 -35.835425   -3.459193     11.966016
# 6009 -32.286200 -35.821899   -3.535698     12.501164
# 6019 -32.141525 -35.797613   -3.656088     13.366978
# 6008 -32.077035 -35.855407   -3.778372     14.276095
# 6020 -31.954767 -35.792694   -3.837927     14.729683
# ...

# %% [markdown]
# # Creating Pipelining

# %%
from sklearn.pipeline import Pipeline
my_pipeline = Pipeline(steps=[('preprocessor', SimpleImputer()),
                              ('model', LinearRegression())
                             ])

# %%
# Multiply by -1 since sklearn calculates *negative* MAE
scores = -1 * cross_val_score(my_pipeline, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("MAE scores:\n", scores)
print("\nAverage MAE score (across experiments):")
print(scores.mean())
# Out:
# MAE scores:
#  [37.94827505 36.90955092 35.30372192 35.38018345 34.55817634]
#
# Average MAE score (across experiments):
# 36.01998153331688

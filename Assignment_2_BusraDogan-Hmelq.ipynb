# %% [markdown]
# # Assigment 2-BusraDogan

# %% [markdown]
# ## Importing Libraries

# %%
# LIBRARIES                         
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import math

# from sklearn.datasets.samples_generator import make_blobs
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# from imblearn.over_sampling import SMOTE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

from sklearn.metrics import roc_curve,roc_auc_score, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score,f1_score

#Machine learning algorithms libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
# import statsmodels.api as sm
from scipy import stats
# import scipy.stats
from scipy.stats import shapiro
from scipy.stats import levene

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.23.1.

# %%
import scipy
scipy.version.full_version
# Out:
# '1.5.0'

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.7

# %%
class datasetAnalysis:
        # LIBRARIES                         
    import pandas as pd
    import numpy as np

    import collections
    import math

    # from sklearn.datasets.samples_generator import make_blobs
    from sklearn.datasets import make_blobs
    from sklearn.model_selection import train_test_split
    from sklearn import metrics
    from sklearn.preprocessing import MinMaxScaler

    from sklearn.preprocessing import LabelEncoder
    from sklearn.preprocessing import OneHotEncoder
    # from imblearn.over_sampling import SMOTE
    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

    from sklearn.metrics import roc_curve,roc_auc_score, auc
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import recall_score
    from sklearn.metrics import precision_score,f1_score

    #Machine learning algorithms libraries
    from sklearn.linear_model import LogisticRegression
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.ensemble import GradientBoostingClassifier
    from sklearn.svm import SVC
    from sklearn.neural_network import MLPClassifier
    import warnings
    warnings.filterwarnings("ignore")
    
    def __init__(self,data,target):
        self.data=data
        self.target=target

    def datasetInfo1(self):
        
        print( '\033[1m'+ "\n Shape of Dataset :" + '\033[0m',self.data.shape)
        print(self.data.info())
        print(self.data.describe())
        print( '\033[1m'+ "\n General Information of Dataset\n" + '\033[0m',self.data.head())
        print('\033[1m'+ " \n Showing Missing Values\n" + '\033[0m')
        print(self.data.isnull().sum())
        
        
    def datasetInfo2(self):
        print(self.data.columns)
        print("\n" , '\033[1m'+ "Target Counts\n" + '\033[0m', self.data[target].value_counts(),"\n")
        
        for i in data.columns:
            print(data[i].value_counts().head(),"\n")
        
        
class PreVisulation:
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    def __init__(self,data,feature):
#         self.data=data
#         self.target=target
        self.feature=feature
        self.data=data

    def vis1(self):
        
    #target distribution
        print(data[target].value_counts())
        sns.set(style="darkgrid")
        ax= sns.countplot(y="reason", hue=target, data=data)
        
#         data[target].value_counts().plot("barh")
    def vis2(self): 
        
        data[feature].plot.hist(bins = 20,figsize=(15,7.5))
        
        
        
    def vis3(self): 
        
        
        for i in range(len(self.data.dtypes)):

               
            
            if (self.data.dtypes[i] != "object" and self.data.iloc[:,i].notna().all()):

                f,axes = newplt.subplots(1,1)
                sns.distplot(self.data.iloc[:,i],kde_kws=dict(linewidth=5),bins = 20)
                
            elif (self.data.dtypes[i] == "object" and self.data.iloc[:,i].notna().all()):
                f,axes = newplt.subplots(1,1)
                sns.countplot(self.data.iloc[:,i],data=self.data)
        
        # Verinin boxplot gösterimi
        newplt.figure()
        sns.boxplot(data=self.data)

# %%
class preprocess():
    global train
    global test
    
    
    def __init__(self):
        preprocess.train=pd.DataFrame()
        preprocess.test=pd.DataFrame()
    
    def split(self):
        
        # train-test spit
        preprocess.train, preprocess.test=train_test_split(data, test_size = 0.3, stratify=data[target],random_state = 42) #shuffle=True
        preprocess.train.reset_index(drop=True, inplace=True)
        preprocess.test.reset_index(drop=True, inplace=True)
        
        print("\n", '\033[1m'+ " Train Info" + '\033[0m')
        print(preprocess.train.info())
        print("\n", '\033[1m'+ " Test Info" + '\033[0m')
        print(preprocess.test.info())

# %% [markdown]
# ## Reading The Dataset

# %%
#read data 
data=pd.read_csv("hmelq.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3576 entries, 0 to 3575
# Data columns (total 13 columns):
# bad        3576 non-null int64
# loan       3576 non-null int64
# mortdue    3262 non-null float64
# value      3512 non-null float64
# reason     3429 non-null object
# job        3409 non-null object
# yoj        3264 non-null float64
# derog      3149 non-null float64
# delinq     3225 non-null float64
# clage      3397 non-null float64
# ninq       3273 non-null float64
# clno       3443 non-null float64
# debtinc    2809 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 363.3+ KB

# %% [markdown]
# # Description of Variables¶

# %% [raw]
# Data Description
# BAD : Target is BAD, which is coded as 0 (good risk) or 1 (bad risk).
# LOAN : Amount of the loan request
# MORTDUE : Amount due on existing mortgage
# VALUE : Value of current property
# REASON : DebtCon = debt consolidation HomeImp = home improvement
# JOB : Six occupational categories
# YOJ : Years at present job
# DEROG : Number of major derogatory reports
# DELINQ : Number of delinquent credit lines
# CLAGE : Age of oldest trade line in months
# NINQ : Number of recent credit lines
# CLNO : Number of credit/trade  lines
# DEBTINC : Debt-to-income ratio

# %%
data.describe()
# data.describe(include='all')
# Out:
#                bad          loan        mortdue          value          yoj  \
# count  3576.000000   3576.000000    3262.000000    3512.000000  3264.000000
# mean      0.199385  18529.697987   74013.907992  101076.922759     8.832644
# std       0.399594  11262.834060   44016.833772   54865.275351     7.568046
# min       0.000000   1100.000000    2619.000000    8800.000000     0.000000
# 25%       0.000000  11000.000000   46700.250000   65753.000000     3.000000
# 50%       0.000000  16200.000000   65858.000000   89183.000000     7.000000
# 75%       0.000000  23100.000000   91717.000000  118928.250000    13.000000
# max       1.000000  89900.000000  399550.000000  850000.000000    41.000000
#
#              derog       delinq        clage         ninq         clno  \
# count  3149.000000  3225.000000  3397.000000  3273.000000  3443.000000
# mean      0.261670     0.432558   179.832529     1.186373    21.507116
# ...

# %%
data.head(5)
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327

# %%
data.shape
# Out:
# (3576, 13)

# %%
data.isnull().sum()
# Out:
# bad          0
# loan         0
# mortdue    314
# value       64
# reason     147
# job        167
# yoj        312
# derog      427
# delinq     351
# clage      179
# ninq       303
# clno       133
# debtinc    767
# dtype: int64

# %%
fig,ax = plt.subplots(figsize=(13, 13))
sns.heatmap(data.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")
plt.show()

# mülkün değer attıkça mortque artar

# %%
sns.violinplot(x ='bad', y ='loan', data = data, hue ='reason',color='yellow')

# %%
column=["loan","mortdue", "yoj"]
color=["r","g","b"]
for i in range(len(column)):
    fig, ax=plt.subplots(figsize=(7,7))
    sns.boxplot(x = "bad", palette=[color[i]],y= column[i], data=data)

# %%
fig, ax=plt.subplots(figsize=(7,7))
sns.scatterplot(x="value", y= "mortdue",hue= "bad",data=data)

# %%
pd.crosstab([data["bad"]],data["reason"],normalize='index').style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_6f8eb0fa_c88e_11ea_b0aa_96e97929c859row0_col0 {
#             background-color:  #008066;
#         }    #T_6f8eb0fa_c88e_11ea_b0aa_96e97929c859row0_col1 {
#             background-color:  #ffff66;
#         }    #T_6f8eb0fa_c88e_11ea_b0aa_96e97929c859row1_col0 {
#             background-color:  #ffff66;
#         }    #T_6f8eb0fa_c88e_11ea_b0aa_96e97929c859row1_col1 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6f8eb0fa_c88e_11ea_b0aa_96e97929c859" >
# <thead>    <tr>
#         <th class="index_name level0" >reason</th>
#         <th class="col_heading level0 col0" >DebtCon</th>
#         <th class="col_heading level0 col1" >HomeImp</th>
#     </tr>    <tr>
#         <th class="index_name level0" >bad</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
# ...

# %%
ax = sns.barplot(x=data.bad, y=data.bad, data=data, estimator=lambda x: len(x) / len(data) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
f, (ax1, ax2,ax3) = plt.subplots(1,3, sharex='col', sharey='row',figsize=(20, 15))
plt.subplot(2,2,1)
sns.distplot(data.loan.dropna(),color="b")
plt.title('Distribution of Loan Amount')
plt.xlabel('LOAN')
plt.ylabel('Frequency')
plt.subplot(2,2,2)
sns.distplot(data.value.dropna(),color="g")
plt.title('Distribution of Value of Current Property')
plt.xlabel('VALUE')
plt.ylabel('Frequency')
plt.subplot(2,2,3)
sns.distplot(data.mortdue.dropna())
plt.title('Distribution of Mortgage Amount Due')
plt.ylabel('Frequency')
plt.xlabel('MORTDUE')
plt.subplot(2,2,4)
#sns.boxplot(y=df.DEROG, x=df.BAD)
plt.title('Distribution of Years at Job')
sns.distplot(data.yoj.dropna())
plt.xlabel('YOJ')
plt.ylabel('Frequency')
plt.subplots_adjust(hspace=.5, wspace = .5)
plt.show()

# %%
print(data["reason"].value_counts())

# This is a nominal feature, 
# It must be modified in a way we can use it.
# Out:
# DebtCon    2371
# HomeImp    1058
# Name: reason, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='reason',data = data, hue = 'bad',palette='GnBu')
plt.show()

# %%
JOB_count= data["job"].value_counts().rename_axis('JOB').reset_index(name='Total Count')
data["job"].value_counts().plot.bar(title='JOB')

# %%
df_hist=data[["loan","clno",'mortdue', "derog","delinq","clage","value", "yoj", "debtinc"]]
df_hist.hist(bins=10,figsize=(20,10))
plt.show()

# %%
data["loan"].plot.hist(bins = 20,figsize=(15,7.5))
# density between 10000-30000 is high

# data["debtinc"].plot.hist(bins = 20,figsize=(15,10))
 
# # Highly populated around 25-50
# # We may cap off the end values if required.

# data["clage"].plot.hist(bins = 20,figsize=(15,10))


# # Density is high around 100-300
# # We can cap off the values >= 600 to get better results

# data["clno"].plot.hist(bins = 20,figsize=(15,10))

# # This distribution looks good and we need not modify anything here.data

# data["value"].plot.hist(bins = 80,figsize=(15,7.5))

# # Concentration is high around 80000-100000
# # There are very less values at the end(>= 400000) that are a bit high compared to mean. We can cap these off.

# data["mortdue"].plot.hist(bins = 40,figsize=(15,7.5))

# # Concentration is high around 40000-100000
# # The values at the end(>= 300000) can be capped off.

# data["yoj"].plot.hist(bins = 40,figsize=(15,7.5))

# # This is very skewed. It would be better 
# # if we modify this variable to decrease the skewness.

# %% [markdown]
# # STATISTIC

# %% [markdown]
# 3- Ortalamalarını karşılaştırcağımız için T TEST i yapıyoruz. (loan normal dağılımdan gelmeli o yüzden shapiro testi yapılmalı)
#
# 1- Shapiro da features bakıyoruz normal davranıştan mı geliyor
#
# 2- Equle varyans bakmamız lazım t test içinde bir parametre çünkü. Levene bad ve good arasına baktım

# %%
df = data.copy()

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Normallik - Shapiro Testi

# %%
for col in df.columns[1:]:           #bad hariç
    if df[col].dtypes != object:
        
        stat, p = shapiro(df[col])

        print('Shapiro Statistics=%.3f, p=%.3f' % (stat, p))

        alpha = 0.05
        if p > alpha:
            print(col)
            print('\033[1m'+ col + '\033[0m','Normal dağılımdan gelmekte (Fail to Reject H0) \n')
        else:
            print('\033[1m'+ col + ":"+'\033[0m','Normal dağılımdan gelmemekte (reject H0)\n')
# Out:
# Shapiro Statistics=0.836, p=0.000
# loan: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.862, p=0.000
# mortdue: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.844, p=0.000
# value: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.912, p=0.000
# yoj: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.277, p=0.000
# derog: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.380, p=0.000
# delinq: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.905, p=0.000
# clage: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.669, p=0.000
# ninq: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.964, p=0.000
# clno: Normal dağılımdan gelmemekte (reject H0)
#
# Shapiro Statistics=0.824, p=0.000
# debtinc: Normal dağılımdan gelmemekte (reject H0)

# %%
# KS testi ikili normal dağılım testi
for col in df.columns[1:]:           #bad hariç
    if df[col].dtypes != object:
        
        p = stats.ks_2samp(df[col][df.bad == 0], df[col][df.bad == 1])[1]

        print('KS Testi  p=%.3f' % ( p))

        alpha = 0.05
        if p > alpha:
            print('\033[1m'+ col + '\033[0m','Normal dağılımdan gelmekte (Fail to Reject H0) \n')
        else:
            print('\033[1m'+ col + ":"+'\033[0m','Normal dağılımdan gelmemekte (reject H0)\n')
# Out:
# KS Testi  p=0.002
# loan: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.005
# mortdue: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.002
# value: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.134
# yoj Normal dağılımdan gelmekte (Fail to Reject H0)
#
# KS Testi  p=0.000
# derog: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.000
# delinq: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.000
# clage: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.004
# ninq: Normal dağılımdan gelmemekte (reject H0)
#
# KS Testi  p=0.069
# clno Normal dağılımdan gelmekte (Fail to Reject H0)
#
# KS Testi  p=0.000
# debtinc: Normal dağılımdan gelmemekte (reject H0)

# %%
stats.ks_2samp(df.clno,df.mortdue)
#iki değişken aynı dağılımdan gelmemekte
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# # LEVENE & Bagimsiz T-Test

# %% [raw]
# *veriler normal dağılımdan gelmemekte. Normallik varsayımı olmadığında levene testi uygulandi
# H0:İki grubun varyansları eşittir
# H1:İki grup varyansları arasında farklılık vardır
# # equal_var parametresi için hesaplanır.
#     # p-value<Lambda ise büyükse equal_var=True, H0 reddedilir,
#     # iki grup varyansı arasında farklılık vardır, heterojen

# %%
# equal_var parametresi için hesaplanır.
# p-value<Lambda ise büyükse equal_var=True, H0 reddedilir, 
# iki grup varyansı arasında farklılık vardır, heterojen
levene(df['loan'][df.bad == 0], df['loan'][df.bad == 1])
# Out:
# LeveneResult(statistic=2.3947745891982195, pvalue=0.12189825252399986)

# %%
for col in df.columns[1:]:           #bad hariç
    if df[col].dtypes != object:
        stat, p=levene(df[col][df.bad == 0], df[col][df.bad == 1])
        print('\033[1m'+ "\nLevene " + col+ '\033[0m'' Statistics=%.3f, p=%.3f' % (stat, p))
        if (levene(df[col][df.bad == 0], df[col][df.bad == 1])[1]) >alpha:
            
            p2=stats.ttest_ind(df[col][df.bad == 0], df[col][df.bad == 1],equal_var=True)[1]
            print('\033[1m'+ "*True Ttest  pvalue=%.3f "% (p2) + '\033[0m' )
            
        else:
            p2=stats.ttest_ind(df[col][df.bad == 0], df[col][df.bad == 1],equal_var=False)[1]
            print('\033[1m'+ "False Ttest  pvalue=%.3f "% (p2) + '\033[0m' )
# Out:
# Levene loan Statistics=2.395, p=0.122
# *True Ttest  pvalue=0.240
#
# Levene mortdue Statistics=2.307, p=0.129
# *True Ttest  pvalue=0.260
#
# Levene value Statistics=3.991, p=0.046
# False Ttest  pvalue=0.263
#
# Levene yoj Statistics=4.210, p=0.040
# False Ttest  pvalue=0.014
#
# Levene derog Statistics=118.586, p=0.000
# False Ttest  pvalue=0.000
#
# Levene delinq Statistics=172.844, p=0.000
# False Ttest  pvalue=0.000
#
# Levene clage Statistics=0.008, p=0.927
# *True Ttest  pvalue=0.000
#
# Levene ninq Statistics=19.275, p=0.000
# False Ttest  pvalue=0.000
#
# Levene clno Statistics=9.247, p=0.002
# False Ttest  pvalue=0.640
#
# Levene debtinc Statistics=115.704, p=0.000
# False Ttest  pvalue=0.000

# %%
# p< 0.05(lamda) ise bu feature ile 
stats.ttest_ind(df['loan'][df.bad == 0],df['loan'][df.bad == 1],equal_var=True)
# Out:
# Ttest_indResult(statistic=1.176054303533842, pvalue=0.23971203285250867)

# %%
# Plotting the KDE Plot 
sns.kdeplot(df.loc[(df['bad']==0),  
            'delinq'], color='#e74c3c', shade=True, Label='repaid')

sns.kdeplot(df.loc[(df['bad']==1), 
            'delinq'], color='#9b59b6', shade=True, Label='not repaid')  
  
plt.xlabel('delinq')
# Out:
# Text(0.5, 0, 'delinq')

# %%
stats.probplot(df['loan'], dist="norm",plot=plt)
plt.show()

# %%
target='bad'
df=datasetAnalysis(data,target)

# %% [markdown]
# # Showing the top 5 elements of each feature

# %%
df.datasetInfo2()
# Out:
# Index(['bad', 'loan', 'mortdue', 'value', 'reason', 'job', 'yoj', 'derog',
#        'delinq', 'clage', 'ninq', 'clno', 'debtinc'],
#       dtype='object')
#
#  Target Counts
#  0    2863
# 1     713
# Name: bad, dtype: int64
#
# 0    2863
# 1     713
# Name: bad, dtype: int64
#
# 15000    65
# 10000    56
# 25000    50
# 20000    42
# 12000    33
# Name: loan, dtype: int64
#
# 50000.0    6
# 55000.0    6
# 45000.0    5
# 62000.0    5
# 42000.0    5
# Name: mortdue, dtype: int64
#
# 80000.0     9
# 65000.0     8
# 125000.0    7
# 85000.0     6
# 60000.0     6
# Name: value, dtype: int64
#
# DebtCon    2371
# HomeImp    1058
# Name: reason, dtype: int64
#
# Other     1431
# ProfEx     767
# Office     569
# Mgr        461
# Self       115
# Name: job, dtype: int64
#
# 0.0    247
# 1.0    223
# 4.0    215
# 2.0    209
# 5.0    205
# Name: yoj, dtype: int64
#
# 0.0    2706
# 1.0     265
# 2.0      98
# 3.0      35
# 4.0      14
# Name: derog, dtype: int64
#
# 0.0    2517
# 1.0     398
# ...

# %% [markdown]
# # Showing the Distribution of the target variable

# %%
feature="loan"
vis=PreVisulation(data,feature)
vis.vis2()

# %%
data.plot(kind = 'box',x='loan',y='clage', rot=0)
plt.show()

# %%
vis.vis1()
# Out:
# 0    2863
# 1     713
# Name: bad, dtype: int64

# %%
vis.vis3()

# %%
# print(data.iloc[:,0:14].notna().all().tolist())
# print(data.columns[data.notna().all()].tolist())
# Out:
# [True, True, False, False, False, False, False, False, False, False, False, False, False]
# ['bad', 'loan']

# %% [markdown]
# ## Label Encoder Function For Encoding Categorial Values

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
def labelEncoder(index, data):
    data.iloc[:,index]=le.fit_transform(data.iloc[:,index])
    return data

# %% [markdown]
# ## One Hot Encoder Function For Encoding Categorial Values

# %%
def oneHotEncoder(feature_index, label, data):
    feature = data.iloc[:,feature_index:feature_index+1].values
    name=(np.unique(data.iloc[:,feature_index]))

    from sklearn.preprocessing import OneHotEncoder
    ohe = OneHotEncoder()
    feature=ohe.fit_transform(feature).toarray()

    #creating a dataframe for all encoded employed
    all_feature_values=pd.DataFrame(feature, index=range(len(feature)), columns=label+"_"+name)

    #adding features to dataset
    data = pd.concat([data, all_feature_values], axis=1)

    return data

# %% [markdown]
# # Splitting the data into train and test

# %%
split=preprocess()

# %%
split.split()
# Out:
#   Train Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2503 entries, 0 to 2502
# Data columns (total 13 columns):
# bad        2503 non-null int64
# loan       2503 non-null int64
# mortdue    2281 non-null float64
# value      2456 non-null float64
# reason     2400 non-null object
# job        2392 non-null object
# yoj        2279 non-null float64
# derog      2204 non-null float64
# delinq     2262 non-null float64
# clage      2380 non-null float64
# ninq       2294 non-null float64
# clno       2411 non-null float64
# debtinc    1961 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 254.3+ KB
# None
#
#   Test Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1073 entries, 0 to 1072
# Data columns (total 13 columns):
# bad        1073 non-null int64
# loan       1073 non-null int64
# mortdue    981 non-null float64
# value      1056 non-null float64
# reason     1029 non-null object
# job        1017 non-null object
# ...

# %% [markdown]
# ### Deleting Outlier age values

# %% [markdown]
# ###  feature before data preprocessing

# %% [markdown]
# ###  feature after data preprocessing

# %% [markdown]
# # Visualization

# %%
column=['loan']

# %%
target
# Out:
# 'bad'

# %%
class afterSpliteVis(preprocess):
    
    import matplotlib.pyplot as plt
    import seaborn as sns
    def __init__(self):
        train=preprocess.train
        train=preprocess.train
    
    
    def vis3(self):
        plt.figure(figsize=(15,6))
        sns.countplot(x=column[0],data = data, hue = target,palette='GnBu')
        plt.show()
        
    def vis4(self):
        import matplotlib.pyplot as plt
        x = train[train[target]== 'Yes'][column[0]].value_counts().head(5)
        x.plot(kind='bar',figsize=(5, 5))
        plt.xlabel("column")
        plt.ylabel("target")
        plt.show()


        # Plotting the KDE Plot 
        sns.kdeplot(train.loc[(train[target]=='Yes'),  
                    column[1]], color='#e74c3c', shade=True, Label='Yes')

        sns.kdeplot(train.loc[(train[target]=='No'), 
                    column[1]], color='#9b59b6', shade=True, Label='No')  

        plt.xlabel('Age')
    def vis5(self):
        import seaborn as sns 
        
        sns.violinplot(x =target, y =column[1], data = train, hue =column[2],color='yellow')

# %%
afterSpliteVis=afterSpliteVis()

# %%
afterSpliteVis.vis3()

# %% [markdown]
# # Handling of missing data

# %% [markdown]
# ## Converting categorical features to numerical features

# %%
def oneHotEncoder(feature_index, label, data):
    feature = data.iloc[:,feature_index:feature_index+1].values
    name=(np.unique(data.iloc[:,feature_index]))

    from sklearn.preprocessing import OneHotEncoder
    ohe = OneHotEncoder()
    feature=ohe.fit_transform(feature).toarray()

    #creating a dataframe for all encoded employed
    all_feature_values=pd.DataFrame(feature, index=range(len(feature)), columns=label+"_"+name)

    #adding features to dataset
    data = pd.concat([data, all_feature_values], axis=1)

    return data

# %%
train=oneHotEncoder(2, "reason", train)

test=oneHotEncoder(2, "reason", test)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
def labelEncoder(index, data):
    data.iloc[:,index]=le.fit_transform(data.iloc[:,index])
    return data

# %%
train=labelEncoder(4,train)
train=labelEncoder(5,train)

# %%
test=labelEncoder(4,test)
test=labelEncoder(5,test)

# %% [markdown]
# # COMING SOON

# %% [markdown]
# # THE END

# %%
# just choose numeric features
for i in np.where(train.dtypes==object):
    train=train.drop(train.iloc[:,i], axis=1)
    test=test.drop(test.iloc[:,i], axis=1)
